# %%
import os
from datetime import datetime
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import *

# Start Spark
spark = SparkSession.builder.appName("FraudTest").getOrCreate()


VALID_CURRENCIES = ["USD", "EUR", "GBP"]
VELOCITY_MAX_TXN = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 8
#       5 from pyspark.sql.types import *
#       7 # Start Spark
# ----> 8 spark = SparkSession.builder.appName("FraudTest").getOrCreate()
#      11 VALID_CURRENCIES = ["USD", "EUR", "GBP"]
#      12 VELOCITY_MAX_TXN = 1
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyspark\sql\session.py:560, in SparkSession.Builder.getOrCreate(self)
#     557     sc = SparkContext.getOrCreate(sparkConf)
#     558     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559     # by all sessions.
# --> 560     session = SparkSession(sc, options=self._options)
#     561 else:
#     562     module = SparkSession._get_j_spark_session_module(session._jvm)
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyspark\sql\session.py:636, in SparkSession.__init__(self, sparkContext, jsparkSession, options)
#     632 jSparkSessionModule = SparkSession._get_j_spark_session_module(self._jvm)
#     634 if jsparkSession is None:
#     635     if (
# --> 636         jSparkSessionClass.getDefaultSession().isDefined()
#     637         and not jSparkSessionClass.getDefaultSession().get().sparkContext().isStopped()
#     638     ):
#     639         jsparkSession = jSparkSessionClass.getDefaultSession().get()
#     640         jSparkSessionModule.applyModifiableSettings(jsparkSession, options)
#
# TypeError: 'JavaPackage' object is not callable
